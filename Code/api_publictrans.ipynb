# %%
# Call libraries
import geopandas as gpd
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
import osmnx as ox
import pandas as pd
from shapely import geometry
import libpysal
import time
from rasterstats import zonal_stats

import warnings
warnings.filterwarnings("ignore")

# %%
# WGS84和GJC坐标系转换函数
# -*- coding: utf-8 -*-
import json
import urllib
import math
# import numpy as np

x_pi = 3.14159265358979324 * 3000.0 / 180.0
pi = 3.1415926535897932384626  # π
a = 6378245.0  # 长半轴
ee = 0.00669342162296594323  # 偏心率平方


'''
输入（经度，维度）
'''
def bd09_to_gcj02(bd_lon, bd_lat):
    """
    百度坐标系(BD-09)转火星坐标系(GCJ-02)
    百度——>谷歌、高德
    :param bd_lat:百度坐标纬度
    :param bd_lon:百度坐标经度
    :return:转换后的坐标列表形式
    """
    x = bd_lon - 0.0065
    y = bd_lat - 0.006
    z = math.sqrt(x * x + y * y) - 0.00002 * math.sin(y * x_pi)
    theta = math.atan2(y, x) - 0.000003 * math.cos(x * x_pi)
    gg_lng = z * math.cos(theta)
    gg_lat = z * math.sin(theta)
    return [gg_lng, gg_lat]
def gcj02_to_wgs84(lng, lat):
    """
    GCJ02(火星坐标系)转GPS84
    :param lng:火星坐标系的经度
    :param lat:火星坐标系纬度
    :return:
    """
    if out_of_china(lng, lat):
        return [lng, lat]
    dlat = _transformlat(lng - 105.0, lat - 35.0)
    dlng = _transformlng(lng - 105.0, lat - 35.0)
    radlat = lat / 180.0 * pi
    magic = math.sin(radlat)
    magic = 1 - ee * magic * magic
    sqrtmagic = math.sqrt(magic)
    dlat = (dlat * 180.0) / ((a * (1 - ee)) / (magic * sqrtmagic) * pi)
    dlng = (dlng * 180.0) / (a / sqrtmagic * math.cos(radlat) * pi)
    mglat = lat + dlat
    mglng = lng + dlng
    return [lng * 2 - mglng, lat * 2 - mglat]
def bd09_to_wgs84(bd_lon, bd_lat):
    lon, lat = bd09_to_gcj02(bd_lon, bd_lat)
    return gcj02_to_wgs84(lon, lat)
def bd09_to_wgs84(bd_lon, bd_lat):
    lon, lat = bd09_to_gcj02(bd_lon, bd_lat)
    return gcj02_to_wgs84(lon, lat)
def gcj02_to_bd09(lng, lat):
    """
    火星坐标系(GCJ-02)转百度坐标系(BD-09)
    谷歌、高德——>百度
    :param lng:火星坐标经度
    :param lat:火星坐标纬度
    :return:
    """
    z = math.sqrt(lng * lng + lat * lat) + 0.00002 * math.sin(lat * x_pi)
    theta = math.atan2(lat, lng) + 0.000003 * math.cos(lng * x_pi)
    bd_lng = z * math.cos(theta) + 0.0065
    bd_lat = z * math.sin(theta) + 0.006
    return [bd_lng, bd_lat]
def wgs84_to_gcj02(lng, lat):
    """
    WGS84转GCJ02(火星坐标系)
    :param lng:WGS84坐标系的经度
    :param lat:WGS84坐标系的纬度
    :return:
    """
    if out_of_china(lng, lat):  # 判断是否在国内
        return [lng, lat]
    dlat = _transformlat(lng - 105.0, lat - 35.0)
    dlng = _transformlng(lng - 105.0, lat - 35.0)
    radlat = lat / 180.0 * pi
    magic = math.sin(radlat)
    magic = 1 - ee * magic * magic
    sqrtmagic = math.sqrt(magic)
    dlat = (dlat * 180.0) / ((a * (1 - ee)) / (magic * sqrtmagic) * pi)
    dlng = (dlng * 180.0) / (a / sqrtmagic * math.cos(radlat) * pi)
    mglat = lat + dlat
    mglng = lng + dlng
    return [mglng, mglat]
def wgs84_to_bd09(lon, lat):
    lon, lat = wgs84_to_gcj02(lon, lat)
    return gcj02_to_bd09(lon, lat)

def out_of_china(lng, lat):
    """
    判断是否在国内，不在国内不做偏移
    :param lng:
    :param lat:
    :return:
    """
    return not (lng > 73.66 and lng < 135.05 and lat > 3.86 and lat < 53.55)

def _transformlng(lng, lat):
    ret = 300.0 + lng + 2.0 * lat + 0.1 * lng * lng + \
          0.1 * lng * lat + 0.1 * math.sqrt(math.fabs(lng))
    ret += (20.0 * math.sin(6.0 * lng * pi) + 20.0 *
            math.sin(2.0 * lng * pi)) * 2.0 / 3.0
    ret += (20.0 * math.sin(lng * pi) + 40.0 *
            math.sin(lng / 3.0 * pi)) * 2.0 / 3.0
    ret += (150.0 * math.sin(lng / 12.0 * pi) + 300.0 *
            math.sin(lng / 30.0 * pi)) * 2.0 / 3.0
    return ret
def _transformlat(lng, lat):
    ret = -100.0 + 2.0 * lng + 3.0 * lat + 0.2 * lat * lat + \
          0.1 * lng * lat + 0.2 * math.sqrt(math.fabs(lng))
    ret += (20.0 * math.sin(6.0 * lng * pi) + 20.0 *
            math.sin(2.0 * lng * pi)) * 2.0 / 3.0
    ret += (20.0 * math.sin(lat * pi) + 40.0 *
            math.sin(lat / 3.0 * pi)) * 2.0 / 3.0
    ret += (160.0 * math.sin(lat / 12.0 * pi) + 320 *
            math.sin(lat * pi / 30.0)) * 2.0 / 3.0
    return ret

# %%
# 转换WGS84坐标为GCJ02的函数
def transform_coordinates(row):
    lng_x, lat_x = wgs84_to_gcj02(row['longitude_x'], row['latitude_x'])
    lng_y, lat_y = wgs84_to_gcj02(row['longitude_y'], row['latitude_y'])
    return pd.Series({'lng_x_gcj02': lng_x, 'lat_x_gcj02': lat_x, 'lng_y_gcj02': lng_y, 'lat_y_gcj02': lat_y})

# %%
# 按照经纬度计算距离的函数
from math import radians, cos, sin, asin, sqrt
 
def haversine(lon1, lat1, lon2, lat2): # 经度1，纬度1，经度2，纬度2 （十进制度数）
    """
    Calculate the great circle distance between two points 
    on the earth (specified in decimal degrees)
    """
    # 将十进制度数转化为弧度
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])
 
    # haversine公式
    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a)) 
    r = 6371 # 地球平均半径，单位为公里
    return c * r * 1000

# %%
pop_resid = gpd.read_file('residential_pop.shp') 
pop_resid = pop_resid.to_crs(epsg = 4326)

pop_resid = pop_resid[(pop_resid['sum_pop'] >= 1)]
pop_resid['cen'] = pop_resid['geometry'].centroid
pop_resid['Popid'] = pop_resid.index + 1

pop_resid['longitude'] = pop_resid['cen'].x
pop_resid['latitude'] = pop_resid['cen'].y

# %%
pop_resid = pop_resid.to_crs(epsg = 3857)
pop_resid['area'] = pop_resid.geometry.area

# %%
pop_resid
# Out:
#         name       sum_pop                                           geometry  \
# 0       None   7276.136558  POLYGON ((12742557.833 2583965.856, 12742480.9...
# 1       None   1217.979429  POLYGON ((12745413.133 2576195.874, 12745295.9...
# 3      ?????   2048.236732  POLYGON ((12709691.109 2588710.751, 12709781.1...
# 4       None  11243.644833  POLYGON ((12702176.654 2585733.443, 12702091.5...
# 5       None    875.631427  POLYGON ((12711043.062 2583066.362, 12711070.5...
# ...      ...           ...                                                ...
# 2076    ????    325.056286  POLYGON ((12690104.222 2594879.791, 12690110.1...
# 2077     ???   6592.324279  POLYGON ((12668653.302 2594538.785, 12668256.1...
# 2078    ????   1589.763618  POLYGON ((12685408.176 2594097.317, 12685432.6...
# 2079    ????    149.804736  POLYGON ((12688879.018 2592578.554, 12688876.6...
# 2080  ??????    305.918748  POLYGON ((12692823.479 2595708.323, 12692891.1...
#
#                              cen  Popid   longitude   latitude  index  \
# 0     POINT (114.47232 22.59552)      1  114.472319  22.595523      1
# 1     POINT (114.48832 22.53681)      2  114.488317  22.536814      1
# 3     POINT (114.17423 22.63940)      4  114.174231  22.639398      1
# 4     POINT (114.10326 22.61540)      5  114.103263  22.615398      1
# 5     POINT (114.18960 22.59443)      6  114.189601  22.594434      1
# ...                          ...    ...         ...        ...    ...
# 2076  POINT (113.99786 22.69175)   2077  113.997858  22.691749      1
# 2077  POINT (113.80420 22.69361)   2078  113.804203  22.693606      1
# 2078  POINT (113.95554 22.68481)   2079  113.955540  22.684806      1
# 2079  POINT (113.98661 22.67397)   2080  113.986614  22.673974      1
# 2080  POINT (114.02230 22.69804)   2081  114.022299  22.698042      1
#
#               area
# 0     2.228591e+06
# 1     6.199168e+05
# 3     2.236799e+05
# 4     4.572930e+05
# 5     3.634558e+05
# ...            ...
# 2076  1.643225e+04
# 2077  3.842189e+05
# 2078  8.869985e+04
# 2079  5.573208e+03
# 2080  4.549872e+04
#
# [1828 rows x 9 columns]

# %%
pop_resid.describe()
# Out:
#             sum_pop        Popid    longitude     latitude   index  \
# count   1828.000000  1828.000000  1828.000000  1828.000000  1828.0
# mean    1029.052911  1038.438184   114.067542    22.613699     1.0
# std     1684.320138   611.388241     0.164655     0.080969     0.0
# min        3.078762     1.000000   113.773104    22.474726     1.0
# 25%      249.581774   505.750000   113.929448    22.547742     1.0
# 50%      540.680846  1020.500000   114.041011    22.594780     1.0
# 75%     1112.315046  1587.250000   114.146364    22.682122     1.0
# max    26058.146784  2081.000000   114.585661    22.808439     1.0
#
#                area
# count  1.828000e+03
# mean   6.372132e+04
# std    9.246396e+04
# min    1.103434e+03
# 25%    1.922322e+04
# 50%    3.662741e+04
# 75%    7.486740e+04
# max    2.228591e+06

# %%
print(pop_resid['sum_pop'].sum())
# Out:
# 1881108.7217623326

# %%
pop_resid = pop_resid.to_crs(epsg = 4326)

# %%
city_park = gpd.read_file('entrance_sim/city_park_entrance.geojson').to_crs(epsg = 4326)
nature_park = gpd.read_file('entrance_sim/nature_park_entrance.geojson').to_crs(epsg = 4326)

# %%
len(city_park)
# Out:
# 208

# %%
len(nature_park)
# Out:
# 58

# %% [markdown]
# ## Public transport

# %%
# 调用高德路径规划api-公交，计算路径距离distance（米），耗时cost（秒）
# 路径规划1.0
import json
from urllib import request

def fetch_GaodeMap_publictrans(df):
    urlbase = 'https://restapi.amap.com/v3/direction/transit/integrated?&key=225cfe7d506a6037debd6a9f4d5aa583&origin={0},{1}&destination={2},{3}&city=0755&time=10:00'
    distances = []
    costs = []
    exceptions = []  # 用来收集引发异常的行索引

    for i, row in df.iterrows():
        x1 = row['lng_x_gcj02']
        y1 = row['lat_x_gcj02']
        x2 = row['lng_y_gcj02']
        y2 = row['lat_y_gcj02']
        url = urlbase.format(x1, y1, x2, y2)

        try:
            html = request.urlopen(url, timeout=15).read()
            js = json.loads(html)
            distance = js['route']['transits'][0]['distance']
            cost = js['route']['transits'][0]['duration']
        except Exception as e:
            print(f"Error processing row {i}: {e}")
            distance = None
            cost = None
            exceptions.append(i)  # 将引发异常的行索引添加到列表中

        distances.append(distance)
        costs.append(cost)

    df['distance'] = distances
    df['cost'] = costs

    return df, exceptions

# %% [markdown]
# ### d) Public transport——City park——Travel time thresholds =30min

# %%
# 1 连接pop和park
pop_resid['index'] = 1
city_park['index'] = 1
OD_d = pd.merge(pop_resid, city_park, on='index').drop('index', axis=1)
len(OD_d)
# Out:
# 380224

# %%
# 2 根据OD左边计算直线距离，得到新列length
OD_d['length'] = OD_d[['longitude_x', 'latitude_x','longitude_y', 'latitude_y',]].\
apply(lambda x:haversine(x[0],x[1],x[2],x[3]),axis=1)

# %%
# 3 筛选lenth<=12km的OD对
f_OD_d = OD_d[(OD_d['length'] <= 12000)]
# 只保留同一个公园直线距离最近的入口
idx = f_OD_d.groupby(['Popid', 'Cityparkid'])['length'].idxmin()
f_OD_d = f_OD_d.loc[idx]
len(f_OD_d)
# Out:
# 41910

# %%
# 4 转换WGS84坐标为GCJ02，便于下一步高德api计算
new_columns = f_OD_d.apply(transform_coordinates, axis=1)
# 合并原始 DataFrame 和新列
f_OD_d_GCJ02 = pd.concat([f_OD_d, new_columns], axis=1)
len(f_OD_d_GCJ02)
# Out:
# 41910

# %%
f_OD_d_GCJ02.head(2)
# Out:
#       name      sum_pop                                         geometry_x  \
# 177   None  7276.136558  POLYGON ((114.46834 22.60207, 114.46765 22.601...
# 570  ?????  2048.236732  POLYGON ((114.17310 22.64141, 114.17391 22.641...
#
#                             cen  Popid  longitude_x  latitude_x  \
# 177  POINT (114.47232 22.59552)      1   114.472319   22.595523
# 570  POINT (114.17423 22.63940)      4   114.174231   22.639398
#
#               area  Cityparkid  count  ...  longitude_y  latitude_y  \
# 177  189186.224851          72      4  ...   114.423113   22.629912
# 570  135493.847185          61      2  ...   114.114103   22.554264
#
#                                             polygonStr  \
# 177  POLYGON ((114.42576 22.631069, 114.425851 22.6...
# 570  POLYGON ((114.110073 22.555798, 114.110462 22....
#
#                      geometry_y        length  lng_x_gcj02  lat_x_gcj02  \
# 177  POINT (114.42311 22.62991)   6335.085074   114.477123    22.592745
# 570  POINT (114.11410 22.55426)  11301.136973   114.179205    22.636635
#
#      lng_y_gcj02  lat_y_gcj02                    geometry
# 177    114.42804    22.627234  POINT (114.47712 22.59275)
# 570    114.11921    22.551578  POINT (114.17921 22.63663)
#
# [2 rows x 21 columns]

# %%
# 导入手动获取的，以为park entrance为起点，在高德公交达到圈界面获取的35-45min公交等时圈
geo_city_capture = gpd.read_file('tmp/geo_city_capture.geojson')

# %%
geo_city_capture
# Out:
#      Cityparkid   longitude   latitude   gcj02_lng  gcj02_lat  \
# 0             1  113.900289  22.481475  113.905151  22.478420
# 1             1  113.894065  22.499114  113.898934  22.496061
# 2             1  113.888705  22.494954  113.893580  22.491903
# 3             1  113.911896  22.508349  113.916754  22.505297
# 4             1  113.901735  22.508829  113.906598  22.505774
# ..          ...         ...        ...         ...        ...
# 203          80  114.388525  22.725322  114.393480  22.722672
# 204          81  114.370117  22.738877  114.375064  22.736214
# 205          82  114.235663  22.736794  114.240511  22.733969
# 206          83  114.229912  22.742795  114.234768  22.739976
# 207          84  114.403277  22.752399  114.408231  22.749761
#
#             gcj02_lng_lat                                           geometry
# 0    113.905151,22.478420  MULTIPOLYGON (((113.92358 22.50266, 113.92325 ...
# 1    113.898934,22.496061  MULTIPOLYGON (((113.91162 22.49606, 113.90527 ...
# 2    113.893580,22.491903  MULTIPOLYGON (((113.91468 22.51992, 113.91431 ...
# 3    113.916754,22.505297  MULTIPOLYGON (((113.92529 22.53038, 113.92505 ...
# 4    113.906598,22.505774  MULTIPOLYGON (((113.91553 22.53482, 113.91537 ...
# ..                    ...                                                ...
# 203  114.393480,22.722672  MULTIPOLYGON (((114.40619 22.72267, 114.39983 ...
# 204  114.375064,22.736214  MULTIPOLYGON (((114.37045 22.76054, 114.37011 ...
# 205  114.240511,22.733969  MULTIPOLYGON (((114.24630 22.75324, 114.24591 ...
# 206  114.234768,22.739976  MULTIPOLYGON (((114.24388 22.75372, 114.24351 ...
# 207  114.408231,22.749761  MULTIPOLYGON (((114.40404 22.76406, 114.40327 ...
#
# [208 rows x 7 columns]

# %%
type(geo_city_capture)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
# 将相同Cityparkid的公园等时圈多边形合并为1个

geo_city_capture['geometry'] = geo_city_capture.geometry.buffer(0)

# 假设你的GeoDataFrame名称是geo_city_capture
dissolved_city_capture = geo_city_capture.dissolve(by='Cityparkid')

# 重置索引以便Cityparkid的公园等时圈多边形合并为1个成为一个正常的列而不是索引
dissolved_city_capture.reset_index(inplace=True)

# 打印结果以确认变化
len(dissolved_city_capture)
# Out:
# 83

# %%
# 筛选在对应公园的公交等时圈中的居住点

import geopandas as gpd
from shapely.geometry import Point

# 假设你已经有了f_OD_d_GCJ02和geo_city_capture两个DataFrame

# 将f_OD_d_GCJ02转换为GeoDataFrame
geometry = [Point(xy) for xy in zip(f_OD_d_GCJ02.lng_x_gcj02, f_OD_d_GCJ02.lat_x_gcj02)]
f_OD_d_gdf = gpd.GeoDataFrame(f_OD_d_GCJ02, geometry=geometry)

# %%
# 设置geo_city_capture的index为Cityparkid，以便后续快速索引
dissolved_city_capture = dissolved_city_capture.set_index('Cityparkid')

# %%
# 筛选点在对应多边形内的行
filtered_rows = []

for idx, row in f_OD_d_gdf.iterrows():
    citypark_id = row['Cityparkid']
    if citypark_id in dissolved_city_capture.index:
        polygon = dissolved_city_capture.loc[citypark_id, 'geometry']
        if row['geometry'].within(polygon):
            filtered_rows.append(row)

# 创建新的DataFrame
filtered_df = pd.DataFrame(filtered_rows).reset_index(drop=True)

# 结果为filtered_df
print(filtered_df)
# Out:
#        name       sum_pop                                         geometry_x  \
# 0      None  11243.644833  POLYGON ((114.1055943 22.6167258, 114.1048299 ...
# 1      None    875.631427  POLYGON ((114.1852426 22.5946077, 114.1854894 ...
# 2      None    244.115629  POLYGON ((114.1832581 22.595519, 114.1804257 2...
# 3     ?????   1987.896567  POLYGON ((114.1294901 22.611478, 114.1293185 2...
# 4     ?????   1987.896567  POLYGON ((114.1294901 22.611478, 114.1293185 2...
# ...     ...           ...                                                ...
# 4447   None    176.790457  POLYGON ((113.9286903 22.7403265, 113.9264084 ...
# 4448   ????    330.748679  POLYGON ((113.8713233 22.7855158, 113.8712439 ...
# 4449   ????    330.748679  POLYGON ((113.8713233 22.7855158, 113.8712439 ...
# 4450   ????    504.475622  POLYGON ((114.0656916 22.6903258, 114.0656006 ...
# 4451   ????   1589.763618  POLYGON ((113.9549605 22.6860643, 113.95518 22...
#
#                                                 cen  Popid  longitude_x  \
# 0     POINT (114.10326302954545 22.615397546071705)      5   114.103263
# 1       POINT (114.18960131902347 22.5944335931523)      6   114.189601
# 2     POINT (114.18245010302873 22.597603101706774)      7   114.182450
# 3      POINT (114.13116027856103 22.61238648747952)      8   114.131160
# 4      POINT (114.13116027856103 22.61238648747952)      8   114.131160
# ...                                             ...    ...          ...
# 4447    POINT (113.9264854853707 22.74055704025272)   2057   113.926485
# 4448  POINT (113.87223493323722 22.784911758282266)   2062   113.872235
# 4449  POINT (113.87223493323722 22.784911758282266)   2062   113.872235
# 4450  POINT (114.06459469558386 22.690906059707242)   2070   114.064595
# 4451    POINT (113.95553989511467 22.6848057872124)   2079   113.955540
#
#       latitude_x          area  Cityparkid  count  ...  longitude_y  \
# 0      22.615398  1.115556e+06          68      8  ...   114.117016
# 1      22.594434  2.814534e+05          70      2  ...   114.169074
# 2      22.597603  2.814534e+05          70      2  ...   114.169074
# 3      22.612386  3.171605e+05          69      3  ...   114.134286
# 4      22.612386  8.759833e+05          71      5  ...   114.132181
# ...          ...           ...         ...    ...  ...          ...
# 4447   22.740557  5.784473e+05          39      7  ...   113.933580
# 4448   22.784912  3.101689e+05          21      3  ...   113.894290
# 4449   22.784912  1.261656e+06          22      9  ...   113.848887
# 4450   22.690906  1.309912e+05          58      3  ...   114.055736
# 4451   22.684806  2.523152e+05          38      3  ...   113.921963
#
#       latitude_y                                         polygonStr  \
# 0      22.583010  POLYGON ((114.120325 22.589701, 114.120698 22....
# 1      22.599424  POLYGON ((114.165136 22.597571, 114.164187 22....
# 2      22.599424  POLYGON ((114.165136 22.597571, 114.164187 22....
# 3      22.598506  POLYGON ((114.140493 22.596965, 114.141001 22....
# 4      22.624478  POLYGON ((114.123718 22.624089, 114.124408 22....
# ...          ...                                                ...
# 4447   22.749282  POLYGON ((113.940671 22.748322, 113.938272 22....
# 4448   22.781506  POLYGON ((113.894966 22.786491, 113.895175 22....
# 4449   22.784651  POLYGON ((113.836786 22.781837, 113.83669 22.7...
# 4450   22.689617  POLYGON ((114.055805 22.689377, 114.058326 22....
# 4451   22.683891  POLYGON ((113.918828 22.682777, 113.919014 22....
#
#                                          geometry_y       length  lng_x_gcj02  \
# 0     POINT (114.11701567821436 22.583009820555464)  3868.193121   114.108387
# 1     POINT (114.16907378966637 22.599423892219875)  2179.159673   114.194532
# 2     POINT (114.16907378966637 22.599423892219875)  1388.022966   114.187400
# 3     POINT (114.13428586090835 22.598506136505293)  1576.420933   114.136241
# 4     POINT (114.13218106829108 22.624477904321836)  1348.580614   114.136241
# ...                                             ...          ...          ...
# 4447  POINT (113.93358027889535 22.749282357540906)  1212.702443   113.931360
# 4448  POINT (113.89428959739818 22.781506359209768)  2292.513815   113.877156
# 4449  POINT (113.84888747634814 22.784650817948044)  2393.709211   113.877156
# 4450  POINT (114.05573555960005 22.689617404962526)   920.075127   114.069725
# 4451  POINT (113.92196335671737 22.683890994729744)  3446.228512   113.960444
#
#       lat_x_gcj02  lng_y_gcj02  lat_y_gcj02  \
# 0       22.612724   114.122120    22.580325
# 1       22.591634   114.174060    22.596663
# 2       22.594817   114.174060    22.596663
# 3       22.609691   114.139359    22.595805
# 4       22.609691   114.137261    22.621783
# ...           ...          ...          ...
# 4447    22.737555   113.938460    22.746292
# 4448    22.781928   113.899177    22.778505
# 4449    22.781928   113.853861    22.781701
# 4450    22.688224   114.060856    22.686920
# 4451    22.681838   113.926833    22.680869
#
#                                            geometry
# 0     POINT (114.10838711259221 22.612724084760575)
# 1       POINT (114.1945319286058 22.59163428654367)
# 2     POINT (114.18739969041458 22.594817210428985)
# 3     POINT (114.13624122560927 22.609691057634272)
# 4     POINT (114.13624122560927 22.609691057634272)
# ...                                             ...
# 4447  POINT (113.93136031603643 22.737554679876176)
# 4448   POINT (113.87715554592786 22.78192797727422)
# 4449   POINT (113.87715554592786 22.78192797727422)
# 4450   POINT (114.06972519683805 22.68822358585989)
# 4451  POINT (113.96044360181413 22.681837828526426)
#
# [4452 rows x 21 columns]

# %%
print(len(pop_resid['Popid'].unique()))
# Out:
# 1828

# %%
print(len(filtered_df['Popid'].unique()))
# Out:
# 1314

# %%
len(filtered_df)
# Out:
# 4452

# %%
# 5 使用api计算高德地图时间距离
start_time = time.time()

ODd_Gaode, exception_rows = fetch_GaodeMap_publictrans(filtered_df)
print("Exception rows:", exception_rows)

end_time = time.time()
execution_time = (end_time - start_time)/60
print("Run time: ", execution_time, "mins")
# Out:
# Error processing row 24: list index out of range
# Error processing row 45: list index out of range
# Error processing row 53: list index out of range
# Error processing row 67: list index out of range
# Error processing row 72: list index out of range
# Error processing row 77: list index out of range
# Error processing row 130: list index out of range
# Error processing row 133: list index out of range
# Error processing row 142: list index out of range
# Error processing row 170: list index out of range
# Error processing row 181: The read operation timed out
# Error processing row 213: list index out of range
# Error processing row 244: list index out of range
# Error processing row 257: list index out of range
# Error processing row 268: list index out of range
# Error processing row 308: list index out of range
# Error processing row 317: list index out of range
# Error processing row 318: list index out of range
# Error processing row 325: list index out of range
# 0  POINT (114.11701567821436 22.583009820555464)  3868.193121  114.108387
# 1  POINT (114.16907378966637 22.599423892219875)  2179.159673  114.194532
#
#   lat_x_gcj02  lng_y_gcj02  lat_y_gcj02  \
# 0   22.612724    114.12212    22.580325
# 1   22.591634    114.17406    22.596663
#
#                                         geometry  distance  cost
# 0  POINT (114.10838711259221 22.612724084760575)      6011  2178
# 1    POINT (114.1945319286058 22.59163428654367)      2974  1927
#
# [2 rows x 23 columns]

# %%
len(ODd_Gaode)
# Out:
# 4452

# %%
print(ODd_Gaode.isnull().sum())
# Out:
# name           909
# sum_pop          0
# geometry_x       0
# cen              0
# Popid            0
# longitude_x      0
# latitude_x       0
# area             0
# Cityparkid       0
# count            0
# avg_area         0
# longitude_y      0
# latitude_y       0
# polygonStr       0
# geometry_y       0
# length           0
# lng_x_gcj02      0
# lat_x_gcj02      0
# lng_y_gcj02      0
# lat_y_gcj02      0
# geometry         0
# distance       388
# cost           388
# dtype: int64

# %%
# 6 检查问题行
exception_df = filtered_df.loc[exception_rows]

len(exception_df)
# Out:
# 400

# %%
# Calculate Gaode map for exception_df travel time and travel distance again
exception_df_re,exception = fetch_GaodeMap_publictrans(exception_df)
# Out:
# Error processing row 24: list index out of range
# Error processing row 45: list index out of range
# Error processing row 53: list index out of range
# Error processing row 67: list index out of range
# Error processing row 72: list index out of range
# Error processing row 77: list index out of range
# Error processing row 130: list index out of range
# Error processing row 133: list index out of range
# Error processing row 142: list index out of range
# Error processing row 170: list index out of range
# Error processing row 213: list index out of range
# Error processing row 244: list index out of range
# Error processing row 257: list index out of range
# Error processing row 268: list index out of range
# Error processing row 308: list index out of range
# Error processing row 317: list index out of range
# Error processing row 318: list index out of range
# Error processing row 325: list index out of range
# Error processing row 334: list index out of range
# Error processing row 335: list index out of range
# Error processing row 340: list index out of range
# Error processing row 345: list index out of range
# Error processing row 349: list index out of range
# Error processing row 353: list index out of range
# Error processing row 358: list index out of range
# Error processing row 362: list index out of range
# Error processing row 366: list index out of range
# Error processing row 413: list index out of range
# Error processing row 448: list index out of range
# Error processing row 449: list index out of range
# Error processing row 458: list index out of range
# Error processing row 461: list index out of range
# Error processing row 473: list index out of range
# Error processing row 481: list index out of range
# Error processing row 503: list index out of range
# Error processing row 510: list index out of range
# Error processing row 516: list index out of range
# Error processing row 553: list index out of range
# Error processing row 562: list index out of range
# Error processing row 565: list index out of range
# Error processing row 567: list index out of range
# Error processing row 568: list index out of range
# Error processing row 586: list index out of range
# Error processing row 589: <urlopen error EOF occurred in violation of protocol (_ssl.c:997)>
# Error processing row 594: list index out of range
# Error processing row 602: list index out of range
# Error processing row 621: list index out of range
# Error processing row 642: list index out of range
# Error processing row 647: list index out of range
# Error processing row 654: list index out of range
# Error processing row 658: list index out of range
# Error processing row 662: list index out of range
# Error processing row 666: list index out of range
# Error processing row 670: list index out of range
# Error processing row 674: list index out of range
# Error processing row 689: list index out of range
# Error processing row 693: list index out of range
# Error processing row 697: list index out of range
# Error processing row 701: list index out of range
# Error processing row 705: list index out of range
# Error processing row 3936: list index out of range
# Error processing row 3944: list index out of range
# Error processing row 3960: list index out of range
# Error processing row 4049: list index out of range
# Error processing row 4061: list index out of range
# Error processing row 4083: list index out of range
# Error processing row 4085: list index out of range
# Error processing row 4102: list index out of range
# Error processing row 4107: list index out of range
# Error processing row 4134: list index out of range
# Error processing row 4138: list index out of range
# Error processing row 4146: list index out of range
# Error processing row 4160: list index out of range
# Error processing row 4186: list index out of range
# Error processing row 4258: list index out of range
# Error processing row 4295: list index out of range
# Error processing row 4296: list index out of range
# Error processing row 4298: list index out of range
# Error processing row 4299: list index out of range
# Error processing row 4338: list index out of range
# Error processing row 4346: list index out of range
# Error processing row 4352: list index out of range
# Error processing row 4374: list index out of range
# Error processing row 4392: list index out of range
# Error processing row 4394: list index out of range
# Error processing row 4407: list index out of range
# Error processing row 4408: list index out of range
# Error processing row 4414: list index out of range
# Error processing row 4417: list index out of range
# Error processing row 4418: list index out of range
# Error processing row 4420: list index out of range
# Error processing row 4432: list index out of range
# Error processing row 4440: list index out of range
# Error processing row 4445: list index out of range

# %%
exception_df_rere = exception_df_re.loc[exception]

# %%
print(len(exception_df_re))
print(len(exception_df_rere))
# Out:
# 400
# 388

# %%
# 提取 cost 列不是空值的行
df_with_cost = exception_df_re[exception_df_re['cost'].notna()]

# 提取 cost 列是空值的行
df_without_cost = exception_df_re[exception_df_re['cost'].isna()]

# %%
ODd_Gaode['distance'] = ODd_Gaode['distance'].combine_first(df_with_cost['distance'])
ODd_Gaode['cost'] = ODd_Gaode['cost'].combine_first(df_with_cost['cost'])

# %%
print(ODe_Gaode.isnull().sum())
# Out:
# name            1295
# sum_pop            0
# geometry_x         0
# cen                0
# Popid              0
# longitude_x        0
# latitude_x         0
# area               0
# Natureparkid       0
# count              0
# avg_area           0
# longitude_y        0
# latitude_y         0
# polygonStr         0
# geometry_y         0
# length             0
# lng_x_gcj02        0
# lat_x_gcj02        0
# lng_y_gcj02        0
# lat_y_gcj02        0
# distance          19
# cost              19
# dtype: int64

# %%
df_without_cost.describe()
# Out:
#            sum_pop        Popid  longitude_x  latitude_x          area  \
# count   388.000000   388.000000   388.000000  388.000000  3.880000e+02
# mean    908.403881   983.608247   114.053802   22.583760  1.269591e+06
# std    1234.888444   506.833684     0.146330    0.078474  1.397440e+06
# min      13.176903    24.000000   113.813920   22.482827  1.083976e+05
# 25%     259.183532   560.750000   113.927715   22.533582  2.096734e+05
# 50%     530.693013  1005.500000   114.045492   22.554366  5.118802e+05
# 75%    1027.273759  1416.000000   114.126741   22.602409  2.142145e+06
# max    9749.345845  2055.000000   114.398138   22.808439  5.042844e+06
#
#        Cityparkid       count       avg_area  longitude_y  latitude_y  \
# count  388.000000  388.000000     388.000000   388.000000  388.000000
# mean    45.139175    9.350515  130900.065686   114.054033   22.583764
# std     23.090010    9.176187   83080.360272     0.146320    0.078483
# min      1.000000    1.000000   21781.119661   113.813122   22.481475
# 25%     30.750000    3.000000   72981.489295   113.926146   22.535059
# 50%     43.000000    6.000000  102376.035070   114.044323   22.554464
# 75%     63.000000   11.250000  178512.061620   114.126116   22.603175
# max     84.000000   36.000000  336189.582370   114.403277   22.812154
#
#             length  lng_x_gcj02  lat_x_gcj02  lng_y_gcj02  lat_y_gcj02
# count   388.000000   388.000000   388.000000   388.000000   388.000000
# mean    435.510677   114.058780    22.580915   114.059011    22.580920
# std     212.748585     0.146348     0.078521     0.146338     0.078531
# min      41.173448   113.818979    22.479772   113.818184    22.478420
# 25%     284.207271   113.932575    22.530858   113.931007    22.532175
# 50%     395.926374   114.050588    22.551643   114.049418    22.551752
# 75%     536.797827   114.131828    22.599569   114.131204    22.600184
# max    1238.813146   114.403092    22.805480   114.408231    22.809197

# %%
# 调用高德路径规划api-步行，计算路径距离distance（米），耗时cost（秒）
# 路径规划1.0
import json
from urllib import request

def fetch_GaodeMap_walking(df):
    urlbase = 'https://restapi.amap.com/v3/direction/walking?&key=225cfe7d506a6037debd6a9f4d5aa583&origin={0},{1}&destination={2},{3}'
    distances = []
    costs = []
    exceptions = []  # 用来收集引发异常的行索引

    for i, row in df.iterrows():
        x1 = row['lng_x_gcj02']
        y1 = row['lat_x_gcj02']
        x2 = row['lng_y_gcj02']
        y2 = row['lat_y_gcj02']
        url = urlbase.format(x1, y1, x2, y2)

        try:
            html = request.urlopen(url, timeout=15).read()
            js = json.loads(html)
            distance = js['route']['paths'][0]['distance']
            cost = js['route']['paths'][0]['duration']
        except Exception as e:
            print(f"Error processing row {i}: {e}")
            distance = None
            cost = None
            exceptions.append(i)  # 将引发异常的行索引添加到列表中

        distances.append(distance)
        costs.append(cost)

    df['distance'] = distances
    df['cost'] = costs

    return df, exceptions

# %%
# 距离过近的OD，使用步行替代公交计算交通耗时
exception_rerere,exception = fetch_GaodeMap_walking(df_without_cost)

# %%
ODd_Gaode['distance'] = ODd_Gaode['distance'].combine_first(exception_rerere['distance'])
ODd_Gaode['cost'] = ODd_Gaode['cost'].combine_first(exception_rerere['cost'])

# %%
print(ODd_Gaode.isnull().sum())
# Out:
# name           909
# sum_pop          0
# geometry_x       0
# cen              0
# Popid            0
# longitude_x      0
# latitude_x       0
# area             0
# Cityparkid       0
# count            0
# avg_area         0
# longitude_y      0
# latitude_y       0
# polygonStr       0
# geometry_y       0
# length           0
# lng_x_gcj02      0
# lat_x_gcj02      0
# lng_y_gcj02      0
# lat_y_gcj02      0
# geometry         0
# distance         0
# cost             0
# dtype: int64

# %%
# 7 转换为数
ODd_Gaode['cost'] = ODd_Gaode['cost'].astype(float)
ODd_Gaode['distance'] = ODd_Gaode['distance'].astype(float)

# %%
ODd_Gaode.describe()
# Out:
#             sum_pop        Popid  longitude_x   latitude_x          area  \
# count   4452.000000  4452.000000  4452.000000  4452.000000  4.452000e+03
# mean    1037.425363  1045.087152   114.032797    22.572366  8.921232e+05
# std     1392.212175   515.269052     0.115613     0.064531  1.086565e+06
# min       13.176903     5.000000   113.773104    22.481635  1.083976e+05
# 25%      300.485102   675.750000   113.928275    22.533937  1.637672e+05
# 50%      610.304947  1112.000000   114.038799    22.553466  3.400115e+05
# 75%     1179.378672  1470.250000   114.094166    22.580345  1.261656e+06
# max    26058.146784  2079.000000   114.429785    22.808439  5.042844e+06
#
#         Cityparkid        count       avg_area  longitude_y   latitude_y  \
# count  4452.000000  4452.000000    4452.000000  4452.000000  4452.000000
# mean     45.062893     6.925651  128029.984941   114.033933    22.573319
# std      20.766336     8.265674   73897.344815     0.114675     0.063569
# min       1.000000     1.000000   21781.119661   113.769368    22.481475
# 25%      31.000000     2.000000   72981.489295   113.930027    22.539624
# 50%      48.000000     4.000000  103389.641930   114.043994    22.552333
# 75%      61.000000     8.000000  170101.961624   114.095008    22.583010
# max      84.000000    36.000000  371885.971015   114.426345    22.812154
#
#              length  lng_x_gcj02  lat_x_gcj02  lng_y_gcj02  lat_y_gcj02  \
# count   4452.000000  4452.000000  4452.000000  4452.000000  4452.000000
# mean    2218.003209   114.037791    22.569523   114.038931    22.570479
# std     1586.302151     0.115651     0.064553     0.114713     0.063592
# min       41.173448   113.778255    22.478591   113.774524    22.478420
# 25%     1074.744839   113.933136    22.530896   113.934893    22.536907
# 50%     1880.145814   114.043885    22.550686   114.049089    22.549625
# 75%     2924.874114   114.099292    22.577529   114.100134    22.580325
# max    10957.148822   114.434702    22.805480   114.431268    22.809197
#
#            distance         cost
# count   4452.000000  4452.000000
# mean    3527.288859  1714.094340
# std     2196.732519   579.456448
# min       56.000000    45.000000
# 25%     2028.000000  1408.750000
# 50%     3154.000000  1727.000000
# 75%     4571.250000  2056.000000
# max    17291.000000  4025.000000

# %%
# 存储
ODd_Gaode.to_csv('tmp/ODd_Gaode.csv',index=False,encoding='utf-8')

# %%
# 8 以30min，即1800s为阈值，计算Ga2SFCA,得到每个popcell的可达性
f_ODd_Gaode = ODd_Gaode[ODd_Gaode['cost'] <= 1800]

f_ODd_Gaode.reset_index(drop = True, inplace = True)

print(len(f_ODd_Gaode))
print(len(f_ODd_Gaode['Popid'].unique()))
# Out:
# 2519
# 1051

# %%
# 9 定义函数
def Ga_1800s(dij):
    e=math.exp(1)
    g=(e**(-0.5*(dij/1800)**2)-e**(-0.5))/(1-e**(-0.5)) # dij是供给和需求之间的长度（时间cost or 距离distance），1800s是阈值（时长or距离）
    return g

def Get_Rj(x):
    x=x.reset_index()
    Sj=x['area'][0]
    
    dt=0
    for i in range(len(x)):
        vl=x['sum_pop'][i]*Ga_1800s(x['cost'][i])
        dt=dt+vl
    return Sj/dt

def Get_Ai(x):
    x=x.reset_index()
    
    dt=0
    for i in range(len(x)):
        vl=x['Rj'][i]*Ga_1800s(x['cost'][i])
        dt=dt+vl
    return dt

# %%
print(len(f_ODd_Gaode))
print(len(f_ODd_Gaode['Popid'].unique()))
# Out:
# 2519
# 1051

# %%
# 10 step1 计算每个公园的Rj
# 公园面积 ➗ 该公园搜索阈以内的人口数

park_s4 = f_ODd_Gaode.groupby(by='Cityparkid').apply(Get_Rj).reset_index()
park_s4 = park_s4.rename(columns={0: 'Rj'})

f_ODd_Gaode = pd.merge(f_ODd_Gaode,park_s4 [['Cityparkid', 'Rj']], on='Cityparkid', how='left')

# %%
# 11 step2 计算每个pop cell的Ai
# 每个供给点popcell,搜索阈以内的Rj,即park_v1
pop_s4 = f_ODd_Gaode.groupby(by='Popid').apply(Get_Ai).reset_index()
pop_s4 = pop_s4.rename(columns={0: 'Ai'})

f_ODd_Gaode = pd.merge(f_ODd_Gaode,pop_s4[['Popid', 'Ai']], on='Popid', how='left')

# %%
print(len(f_ODd_Gaode))
print(len(f_ODd_Gaode['Popid'].unique()))
# Out:
# 2519
# 1051

# %%
f_ODd_Gaode.columns
# Out:
# Index(['name', 'sum_pop', 'geometry_x', 'cen', 'Popid', 'longitude_x',
#        'latitude_x', 'area', 'Cityparkid', 'count', 'avg_area', 'longitude_y',
#        'latitude_y', 'polygonStr', 'geometry_y', 'length', 'lng_x_gcj02',
#        'lat_x_gcj02', 'lng_y_gcj02', 'lat_y_gcj02', 'geometry', 'distance',
#        'cost', 'Rj', 'Ai'],
#       dtype='object')

# %%
# 12 简化
access_socre_d = f_ODd_Gaode[['Popid', 'sum_pop', 'Ai']]

# %%
access_socre_d.drop_duplicates(inplace=True)
len(access_socre_d)
# Out:
# 1051

# %%
#13 存储
result_d = pop_resid.merge(access_socre_d[['Popid', 'Ai']], on='Popid', how='left')
result_d = result_d[['sum_pop', 'geometry', 'Popid', 'Ai']]

# %%
result_d.fillna(0, inplace=True)

# %%
result_d.to_file('tmp/result_d.geojson')

# %% [markdown]
# ### e) Public transport——Natural park——Travel time thresholds =60min , Use the bus to reach the circle polygon filter

# %%
# # 1 连接pop和park
# pop_resid['index'] = 1
# nature_park['index'] = 1
# OD_e = pd.merge(pop_resid, nature_park, on='index').drop('index', axis=1)
# len(OD_e)
# Out:
# 106024

# %%
# # 2 根据OD左边计算直线距离，得到新列length
# OD_e['length'] = OD_e[['longitude_x', 'latitude_x','longitude_y', 'latitude_y',]].\
# apply(lambda x:haversine(x[0],x[1],x[2],x[3]),axis=1)

# %%
# # 3 筛选lenth<=30km的OD对
# f_OD_e = OD_e[(OD_e['length'] <= 30000)]
# # 只保留同一个公园直线距离最近的入口
# idx = f_OD_e.groupby(['Popid', 'Natureparkid'])['length'].idxmin()
# f_OD_e = f_OD_e.loc[idx]
# len(f_OD_e)
# Out:
# 10736

# %%
# len(f_OD_e['Popid'].unique())
# Out:
# 1828

# %%
# # 4 转换WGS84坐标为GCJ02，便于下一步高德api计算
# new_columns = f_OD_e.apply(transform_coordinates, axis=1)
# # 合并原始 DataFrame 和新列
# f_OD_e_GCJ02 = pd.concat([f_OD_e, new_columns], axis=1)
# len(f_OD_e_GCJ02)
# Out:
# 10736

# %%
# # 导入手动获取的，以为park entrance为起点，在高德公交达到圈界面获取的35-45min公交等时圈
# geo_nature_capture = gpd.read_file('tmp/geo_nature_capture.geojson')

# %%
# # 将相同Cityparkid的公园等时圈多边形合并为1个

# geo_nature_capture['geometry'] = geo_nature_capture.geometry.buffer(0)

# # 假设你的GeoDataFrame名称是geo_city_capture
# dissolved_nature_capture = geo_nature_capture.dissolve(by='Natureparkid')

# # 重置索引以便Cityparkid的公园等时圈多边形合并为1个成为一个正常的列而不是索引
# dissolved_nature_capture.reset_index(inplace=True)

# # 打印结果以确认变化
# len(dissolved_nature_capture)
# Out:
# 9

# %%
# # 筛选在对应公园的公交等时圈中的居住点

# import geopandas as gpd
# from shapely.geometry import Point

# # 将f_OD_e_GCJ02转换为GeoDataFrame
# geometry = [Point(xy) for xy in zip(f_OD_e_GCJ02.lng_x_gcj02, f_OD_e_GCJ02.lat_x_gcj02)]
# f_OD_e_gdf = gpd.GeoDataFrame(f_OD_e_GCJ02, geometry=geometry)

# %%
# # 设置geo_nature_capture的index为Natureparkid，以便后续快速索引
# dissolved_nature_capture = dissolved_nature_capture.set_index('Natureparkid')

# %%
# # 筛选点在对应多边形内的行
# filtered_rows_e = []

# for idx, row in f_OD_e_gdf.iterrows():
#     naturepark_id = row['Natureparkid']
#     if naturepark_id in dissolved_nature_capture.index:
#         polygon = dissolved_nature_capture.loc[naturepark_id, 'geometry']
#         if row['geometry'].within(polygon):
#             filtered_rows_e.append(row)

# # 创建新的DataFrame
# filtered_df_e = pd.DataFrame(filtered_rows_e).reset_index(drop=True)

# # 结果为filtered_df
# print(filtered_df_e)
# Out:
#        name       sum_pop                                         geometry_x  \
# 0      None   7276.136558  POLYGON ((114.4683446 22.6020676, 114.4676535 ...
# 1      None   7276.136558  POLYGON ((114.4683446 22.6020676, 114.4676535 ...
# 2      None   1217.979429  POLYGON ((114.4939942 22.5376144, 114.4929416 ...
# 3      None  11243.644833  POLYGON ((114.1055943 22.6167258, 114.1048299 ...
# 4      ????    480.767980  POLYGON ((114.1330173 22.6159002, 114.1339508 ...
# ..      ...           ...                                                ...
# 632  ??????    294.324127  POLYGON ((113.9913625 22.6733559, 113.9900255 ...
# 633     ???    169.534223  POLYGON ((113.9948493 22.6677921, 113.9952047 ...
# 634     ???     96.565294  POLYGON ((113.9404252 22.6761329, 113.9404043 ...
# 635    ????   1589.763618  POLYGON ((113.9549605 22.6860643, 113.95518 22...
# 636    ????    149.804736  POLYGON ((113.9861396 22.673476, 113.9861186 2...
#
#                                                cen  Popid  longitude_x  \
# 0    POINT (114.47231850239282 22.595522718602506)      1   114.472319
# 1    POINT (114.47231850239282 22.595522718602506)      1   114.472319
# 2    POINT (114.48831673423224 22.536813771809264)      2   114.488317
# 3    POINT (114.10326302954545 22.615397546071705)      5   114.103263
# 4    POINT (114.13310203204038 22.615018314693973)      9   114.133102
# ..                                             ...    ...          ...
# 632    POINT (113.99039781148953 22.6735249022793)   2074   113.990398
# 633   POINT (113.99440690501734 22.66698509891354)   2075   113.994407
# 634  POINT (113.94158172024504 22.676379576784868)   2076   113.941582
# 635    POINT (113.95553989511467 22.6848057872124)   2079   113.955540
# 636   POINT (113.98661415051684 22.67397395954415)   2080   113.986614
#
#      latitude_x          area  Natureparkid  count  ...  longitude_y  \
# 0     22.595523  5.492925e+07             4     15  ...   114.520401
# 1     22.595523  5.026383e+06             7      6  ...   114.461853
# 2     22.536814  5.492925e+07             4     15  ...   114.520401
# 3     22.615398  1.610089e+06             8      3  ...   114.109389
# 4     22.615018  1.610089e+06             8      3  ...   114.115443
# ..          ...           ...           ...    ...  ...          ...
# 632   22.673525  4.117929e+07             2     20  ...   113.983869
# 633   22.666985  4.117929e+07             2     20  ...   113.983869
# 634   22.676380  4.117929e+07             2     20  ...   113.942765
# 635   22.684806  4.117929e+07             2     20  ...   113.964573
# 636   22.673974  4.117929e+07             2     20  ...   113.983869
#
#      latitude_y                                         polygonStr  \
# 0     22.546830  POLYGON ((114.555858 22.554677, 114.556354 22....
# 1     22.588642  POLYGON ((114.447645 22.575547, 114.447186 22....
# 2     22.546830  POLYGON ((114.555858 22.554677, 114.556354 22....
# 3     22.632964  POLYGON ((114.108256 22.6327, 114.10808 22.632...
# 4     22.632140  POLYGON ((114.108256 22.6327, 114.10808 22.632...
# ..          ...                                                ...
# 632   22.670344  POLYGON ((113.979706 22.672994, 113.97967 22.6...
# 633   22.670344  POLYGON ((113.979706 22.672994, 113.97967 22.6...
# 634   22.667990  POLYGON ((113.979706 22.672994, 113.97967 22.6...
# 635   22.682352  POLYGON ((113.979706 22.672994, 113.97967 22.6...
# 636   22.670344  POLYGON ((113.979706 22.672994, 113.97967 22.6...
#
#                                         geometry_y       length  lng_x_gcj02  \
# 0     POINT (114.5204013407297 22.546830495831678)  7327.298271   114.477123
# 1     POINT (114.46185267415281 22.58864168468168)  1319.039449   114.477123
# 2     POINT (114.5204013407297 22.546830495831678)  3478.232858   114.493063
# 3     POINT (114.10938885890067 22.63296430770934)  2052.032223   114.108387
# 4    POINT (114.11544301256858 22.632139608403932)  2628.613702   114.138179
# ..                                             ...          ...          ...
# 632   POINT (113.98386882683009 22.67034394218838)   757.536620   113.995377
# 633   POINT (113.98386882683009 22.67034394218838)  1143.946833   113.999395
# 634  POINT (113.94276476463533 22.667990335677256)   940.705212   113.946465
# 635    POINT (113.9645729914416 22.68235212936183)   966.067189   113.960444
# 636   POINT (113.98386882683009 22.67034394218838)   492.205919   113.991584
#
#      lat_x_gcj02  lng_y_gcj02  lat_y_gcj02  \
# 0      22.592745   114.525036    22.543907
# 1      22.592745   114.466690    22.585890
# 2      22.533985   114.525036    22.543907
# 3      22.612724   114.114507    22.630292
# 4      22.612321   114.120553    22.629463
# ..           ...          ...          ...
# 632    22.670648   113.988831    22.667447
# 633    22.664119   113.988831    22.667447
# 634    22.673382   113.947649    22.664993
# 635    22.681838   113.969493    22.679405
# 636    22.671086   113.988831    22.667447
#
#                                           geometry
# 0    POINT (114.47712338497112 22.592745038547314)
# 1    POINT (114.47712338497112 22.592745038547314)
# 2     POINT (114.49306330242949 22.53398470069808)
# 3    POINT (114.10838711259221 22.612724084760575)
# 4    POINT (114.13817909272946 22.612320802058452)
# ..                                             ...
# 632   POINT (113.99537671281938 22.67064830291413)
# 633   POINT (113.99939545029035 22.66411908604516)
# 634     POINT (113.9464648353621 22.6733816435684)
# 635  POINT (113.96044360181413 22.681837828526426)
# 636     POINT (113.9915837060292 22.6710861965924)
#
# [637 rows x 21 columns]

# %%
# print(len(pop_resid['Popid'].unique()))
# Out:
# 1828

# %%
# print(len(filtered_df_e['Popid'].unique()))
# Out:
# 560

# %%
# len(filtered_df_e)
# Out:
# 637

# %%
# # 5 使用api计算高德地图时间距离
# start_time = time.time()

# ODe_Gaode, exception_rows = fetch_GaodeMap_publictrans(filtered_df_e)
# print("Exception rows:", exception_rows)

# end_time = time.time()
# execution_time = (end_time - start_time)/60
# print("Run time: ", execution_time, "mins")
# Out:
# Error processing row 7: list index out of range
# Error processing row 9: list index out of range
# Error processing row 11: list index out of range
# Error processing row 59: list index out of range
# Error processing row 60: list index out of range
# Error processing row 85: list index out of range
# Error processing row 87: list index out of range
# Error processing row 110: list index out of range
# Error processing row 111: list index out of range
# Error processing row 112: list index out of range
# Error processing row 116: list index out of range
# Error processing row 120: list index out of range
# Error processing row 135: list index out of range
# Error processing row 136: list index out of range
# Error processing row 141: list index out of range
# Error processing row 149: list index out of range
# Error processing row 150: list index out of range
# Error processing row 151: list index out of range
# Error processing row 152: list index out of range
# Error processing row 158: list index out of range
# Error processing row 159: list index out of range
# Error processing row 160: list index out of range
# Error processing row 161: list index out of range
# Error processing row 163: list index out of range
# Error processing row 194: list index out of range
# Error processing row 197: list index out of range
# Error processing row 198: list index out of range
# Error processing row 200: list index out of range
# Error processing row 201: list index out of range
# Error processing row 202: list index out of range
# Error processing row 203: list index out of range
# Error processing row 204: list index out of range
# Error processing row 207: list index out of range
# Error processing row 208: list index out of range
# Error processing row 209: list index out of range
# Error processing row 215: list index out of range
# Error processing row 234: list index out of range
# Error processing row 236: list index out of range
# Error processing row 297: list index out of range
# Error processing row 320: list index out of range
# Error processing row 321: list index out of range
# Error processing row 350: list index out of range
# Error processing row 359: list index out of range
# Error processing row 395: list index out of range
# Error processing row 398: list index out of range
# Error processing row 399: list index out of range
# Error processing row 404: list index out of range
# Error processing row 406: list index out of range
# Error processing row 407: list index out of range
# Error processing row 424: list index out of range
# Error processing row 425: list index out of range
# Error processing row 426: list index out of range
# Error processing row 428: list index out of range
# Error processing row 433: list index out of range
# Error processing row 441: list index out of range
# Error processing row 442: list index out of range
# Error processing row 444: list index out of range
# Error processing row 445: list index out of range
# Error processing row 446: list index out of range
# Error processing row 463: The read operation timed out
# Error processing row 476: list index out of range
# Error processing row 506: list index out of range
# Error processing row 507: list index out of range
# Error processing row 516: list index out of range
# Error processing row 525: list index out of range
# Error processing row 552: list index out of range
# Error processing row 553: list index out of range
# Error processing row 556: list index out of range
# Error processing row 558: list index out of range
# Error processing row 581: list index out of range
# Error processing row 586: list index out of range
# Error processing row 589: list index out of range
# Error processing row 591: list index out of range
# Error processing row 592: list index out of range
# Error processing row 598: list index out of range
# Error processing row 609: list index out of range
# Error processing row 627: list index out of range
# Error processing row 629: list index out of range
# Error processing row 631: list index out of range
# Error processing row 636: list index out of range
# Exception rows: [7, 9, 11, 59, 60, 85, 87, 110, 111, 112, 116, 120, 135, 136, 141, 149, 150, 151, 152, 158, 159, 160, 161, 163, 194, 197, 198, 200, 201, 202, 203, 204, 207, 208, 209, 215, 234, 236, 297, 320, 321, 350, 359, 395, 398, 399, 404, 406, 407, 424, 425, 426, 428, 433, 441, 442, 444, 445, 446, 463, 476, 506, 507, 516, 525, 552, 553, 556, 558, 581, 586, 589, 591, 592, 598, 609, 627, 629, 631, 636]
# Run time:  12.226085770130158 mins

# %%
# len(ODe_Gaode)
# Out:
# 637

# %%
# nan_cost_df = ODe_Gaode[ODe_Gaode['cost'].isna()]
# len(nan_cost_df)
# Out:
# 80

# %%
# # 调用高德路径规划api-步行，计算路径距离distance（米），耗时cost（秒）
# # 路径规划1.0
# import json
# from urllib import request

# def fetch_GaodeMap_walking(df):
#     urlbase = 'https://restapi.amap.com/v3/direction/walking?&key=225cfe7d506a6037debd6a9f4d5aa583&origin={0},{1}&destination={2},{3}'
#     distances = []
#     costs = []
#     exceptions = []  # 用来收集引发异常的行索引

#     for i, row in df.iterrows():
#         x1 = row['lng_x_gcj02']
#         y1 = row['lat_x_gcj02']
#         x2 = row['lng_y_gcj02']
#         y2 = row['lat_y_gcj02']
#         url = urlbase.format(x1, y1, x2, y2)

#         try:
#             html = request.urlopen(url, timeout=15).read()
#             js = json.loads(html)
#             distance = js['route']['paths'][0]['distance']
#             cost = js['route']['paths'][0]['duration']
#         except Exception as e:
#             print(f"Error processing row {i}: {e}")
#             distance = None
#             cost = None
#             exceptions.append(i)  # 将引发异常的行索引添加到列表中

#         distances.append(distance)
#         costs.append(cost)

#     df['distance'] = distances
#     df['cost'] = costs

#     return df, exceptions

# %%
# # 对nan行重新计算
# exception_df_re,exception = fetch_GaodeMap_walking(nan_cost_df)

# %%
# exception
# Out:
# []

# %%
# ODe_Gaode['distance'] = ODe_Gaode['distance'].combine_first(exception_df_re['distance'])
# ODe_Gaode['cost'] = ODe_Gaode['cost'].combine_first(exception_df_re['cost'])

# %%
# print(ODe_Gaode.isnull().sum())
# Out:
# name            152
# sum_pop           0
# geometry_x        0
# cen               0
# Popid             0
# longitude_x       0
# latitude_x        0
# area              0
# Natureparkid      0
# count             0
# avg_area          0
# longitude_y       0
# latitude_y        0
# polygonStr        0
# geometry_y        0
# length            0
# lng_x_gcj02       0
# lat_x_gcj02       0
# lng_y_gcj02       0
# lat_y_gcj02       0
# geometry          0
# distance          0
# cost              0
# dtype: int64

# %%
# # 7 转换为数
# ODe_Gaode['cost'] = ODe_Gaode['cost'].astype(float)
# ODe_Gaode['distance'] = ODe_Gaode['distance'].astype(float)

# %%
# ODe_Gaode.describe()
# Out:
#             sum_pop        Popid  longitude_x  latitude_x          area  \
# count    637.000000   637.000000   637.000000  637.000000  6.370000e+02
# mean    1093.314082  1164.153846   114.020148   22.582287  1.581991e+07
# std     1508.346618   477.720658     0.121925    0.059438  1.501405e+07
# min       10.682643     1.000000   113.804838   22.492294  3.116790e+05
# 25%      298.173479   797.000000   113.948400   22.537980  4.675047e+05
# 50%      580.240654  1153.000000   113.997629   22.560335  2.290202e+07
# 75%     1183.283550  1530.000000   114.048959   22.623779  2.290202e+07
# max    11519.272830  2080.000000   114.574451   22.745957  5.492925e+07
#
#        Natureparkid       count      avg_area  longitude_y  latitude_y  \
# count    637.000000  637.000000  6.370000e+02   637.000000  637.000000
# mean       5.001570   12.472527  9.398625e+05   114.019598   22.583713
# std        2.217355    9.697044  6.620219e+05     0.123049    0.055962
# min        1.000000    1.000000  3.116790e+05   113.823613   22.503005
# 25%        3.000000    1.000000  3.769553e+05   113.952972   22.539463
# 50%        6.000000   17.000000  1.041001e+06   113.984552   22.572901
# 75%        6.000000   22.000000  1.041001e+06   114.048522   22.626122
# max        9.000000   22.000000  3.661950e+06   114.569193   22.727077
#
#              length  lng_x_gcj02  lat_x_gcj02  lng_y_gcj02  lat_y_gcj02  \
# count    637.000000   637.000000   637.000000   637.000000   637.000000
# mean    2658.810684   114.025118    22.579412   114.024561    22.580830
# std     1950.619265     0.121912     0.059470     0.123025     0.056004
# min       76.327740   113.809920    22.489243   113.828646    22.499974
# 25%     1148.028475   113.953290    22.535151   113.957865    22.536549
# 50%     2169.375122   114.002621    22.557492   113.989508    22.570171
# 75%     3581.362324   114.054060    22.621025   114.053626    22.623278
# max    11443.674812   114.578948    22.743130   114.573699    22.724254
#
#            distance          cost
# count    637.000000    637.000000
# mean    4834.270016   2347.400314
# std     3408.508470   1727.234906
# min       80.000000     64.000000
# 25%     2415.000000   1641.000000
# 50%     4157.000000   2019.000000
# 75%     6022.000000   2497.000000
# max    18613.000000  12032.000000

# %%
# # 存储
# ODe_Gaode.to_csv('tmp/ODe_Gaode.csv',index=False,encoding='utf-8')

# %%
# # 8 以30min，即1800s为阈值，计算Ga2SFCA,得到每个popcell的可达性
# f_ODe_Gaode = ODe_Gaode[ODe_Gaode['cost'] <= 1800]

# f_ODe_Gaode.reset_index(drop = True, inplace = True)

# print(len(f_ODe_Gaode))
# print(len(f_ODe_Gaode['Popid'].unique()))
# Out:
# 231
# 230

# %%
# # 9 定义函数
# def Ga_1800s(dij):
#     e=math.exp(1)
#     g=(e**(-0.5*(dij/1800)**2)-e**(-0.5))/(1-e**(-0.5)) # dij是供给和需求之间的长度（时间cost or 距离distance），1800s是阈值（时长or距离）
#     return g

# def Get_Rj(x):
#     x=x.reset_index()
#     Sj=x['area'][0]
    
#     dt=0
#     for i in range(len(x)):
#         vl=x['sum_pop'][i]*Ga_1800s(x['cost'][i])
#         dt=dt+vl
#     return Sj/dt

# def Get_Ai(x):
#     x=x.reset_index()
    
#     dt=0
#     for i in range(len(x)):
#         vl=x['Rj'][i]*Ga_1800s(x['cost'][i])
#         dt=dt+vl
#     return dt

# %%
# # 10 step1 计算每个公园的Rj
# # 公园面积 ➗ 该公园搜索阈以内的人口数

# park_s5 = f_ODe_Gaode.groupby(by='Natureparkid').apply(Get_Rj).reset_index()
# park_s5 = park_s5.rename(columns={0: 'Rj'})

# f_ODe_Gaode = pd.merge(f_ODe_Gaode,park_s5[['Natureparkid', 'Rj']], on='Natureparkid', how='left')

# # 11 step2 计算每个pop cell的Ai
# # 每个供给点popcell,搜索阈以内的Rj,即park_v1
# pop_s5 = f_ODe_Gaode.groupby(by='Popid').apply(Get_Ai).reset_index()
# pop_s5 = pop_s5.rename(columns={0: 'Ai'})

# f_ODe_Gaode = pd.merge(f_ODe_Gaode,pop_s5[['Popid', 'Ai']], on='Popid', how='left')

# print(len(f_ODe_Gaode))
# print(len(f_ODe_Gaode['Popid'].unique()))
# Out:
# 231
# 230

# %%
# #13 存储
# result_e = pop_resid.merge(access_socre_e[['Popid', 'Ai']], on='Popid', how='left')
# result_e = result_e[['sum_pop', 'geometry', 'Popid', 'Ai']]

# result_e.fillna(0, inplace=True)

# result_e.to_file('tmp/result_e.geojson')

# %% [markdown]
# ### e) Public transport——Natural park——Travel time thresholds =60min

# %%
# 1 连接pop和park
pop_resid['index'] = 1
nature_park['index'] = 1
OD_e = pd.merge(pop_resid, nature_park, on='index').drop('index', axis=1)
len(OD_e)
# Out:
# 106024

# %%
# 2 根据OD左边计算直线距离，得到新列length
OD_e['length'] = OD_e[['longitude_x', 'latitude_x','longitude_y', 'latitude_y',]].\
apply(lambda x:haversine(x[0],x[1],x[2],x[3]),axis=1)

# %%
# 3 筛选lenth<=20km的OD对
f_OD_e = OD_e[(OD_e['length'] <= 20000)]
# 只保留同一个公园直线距离最近的入口
idx = f_OD_e.groupby(['Popid', 'Natureparkid'])['length'].idxmin()
f_OD_e = f_OD_e.loc[idx]
len(f_OD_e)
# Out:
# 7749

# %%
len(f_OD_e['Popid'].unique())
# Out:
# 1828

# %%
# 4 转换WGS84坐标为GCJ02，便于下一步高德api计算
new_columns = f_OD_e.apply(transform_coordinates, axis=1)
# 合并原始 DataFrame 和新列
f_OD_e_GCJ02 = pd.concat([f_OD_e, new_columns], axis=1)
len(f_OD_e_GCJ02)
# Out:
# 7749

# %%
# 5 使用api计算高德地图时间距离
start_time = time.time()

ODe_Gaode, exception_rows = fetch_GaodeMap_publictrans(f_OD_e_GCJ02)
print("Exception rows:", exception_rows)

end_time = time.time()
execution_time = (end_time - start_time)/60
print("Run time: ", execution_time, "mins")
# Out:
# Error processing row 3042: list index out of range
# Error processing row 5739: list index out of range
# Error processing row 5854: list index out of range
# Error processing row 8757: list index out of range
# Error processing row 8931: list index out of range
# Error processing row 16007: list index out of range
# Error processing row 16181: list index out of range
# Error processing row 30739: list index out of range
# Error processing row 30797: list index out of range
# Error processing row 34601: list index out of range
# Error processing row 34621: list index out of range
# Error processing row 35206: list index out of range
# Error processing row 35322: list index out of range
# Error processing row 36988: list index out of range
# Error processing row 37046: list index out of range
# Error processing row 37104: list index out of range
# Error processing row 37162: list index out of range
# Error processing row 37220: list index out of range
# Error processing row 38677: list index out of range
# Error processing row 39419: list index out of range
# Error processing row 40942: list index out of range
# Error processing row 40987: list index out of range
# Error processing row 41159: list index out of range
# Error processing row 41869: list index out of range
# Error processing row 41927: list index out of range
# Error processing row 41985: list index out of range
# Error processing row 42043: list index out of range
# Error processing row 42333: list index out of range
# Error processing row 42391: list index out of range
# Error processing row 42449: list index out of range
# Error processing row 42507: list index out of range
# Error processing row 42730: list index out of range
# Error processing row 47525: list index out of range
# Error processing row 47734: list index out of range
# Error processing row 48066: list index out of range
# Error processing row 48124: list index out of range
# Error processing row 48182: list index out of range
# Error processing row 48298: list index out of range
# Error processing row 48356: list index out of range
# sum_pop            0
# geometry_x         0
# cen                0
# Popid              0
# longitude_x        0
# latitude_x         0
# area               0
# Natureparkid       0
# count              0
# avg_area           0
# longitude_y        0
# latitude_y         0
# polygonStr         0
# geometry_y         0
# length             0
# lng_x_gcj02        0
# lat_x_gcj02        0
# lng_y_gcj02        0
# lat_y_gcj02        0
# distance         104
# cost             104
# dtype: int64
# 1828

# %%
# 6 检查问题行
exception_df = f_OD_e_GCJ02.loc[exception_rows]

len(exception_df)
# Out:
# 104

# %%
# Calculate Gaode map for exception_df travel time and travel distance again
exception_df_re,exception = fetch_GaodeMap_publictrans(exception_df)
# Out:
# Error processing row 3042: list index out of range
# Error processing row 5739: list index out of range
# Error processing row 5854: list index out of range
# Error processing row 8757: list index out of range
# Error processing row 8931: list index out of range
# Error processing row 16007: list index out of range
# Error processing row 16181: list index out of range
# Error processing row 30739: list index out of range
# Error processing row 30797: list index out of range
# Error processing row 34601: list index out of range
# Error processing row 34621: list index out of range
# Error processing row 35206: list index out of range
# Error processing row 35322: list index out of range
# Error processing row 36988: list index out of range
# Error processing row 37046: list index out of range
# Error processing row 37104: list index out of range
# Error processing row 37162: list index out of range
# Error processing row 37220: list index out of range
# Error processing row 38677: list index out of range
# Error processing row 39419: list index out of range
# Error processing row 40942: list index out of range
# Error processing row 40987: list index out of range
# Error processing row 41159: list index out of range
# Error processing row 41869: list index out of range
# Error processing row 41927: list index out of range
# Error processing row 41985: list index out of range
# Error processing row 42043: list index out of range
# Error processing row 42333: list index out of range
# Error processing row 42391: list index out of range
# Error processing row 42449: list index out of range
# Error processing row 42507: list index out of range
# Error processing row 42730: list index out of range
# Error processing row 47525: list index out of range
# Error processing row 47734: list index out of range
# Error processing row 48066: list index out of range
# Error processing row 48124: list index out of range
# Error processing row 48182: list index out of range
# Error processing row 48298: list index out of range
# Error processing row 48356: list index out of range
# Error processing row 48414: list index out of range
# Error processing row 48472: list index out of range
# Error processing row 48530: list index out of range
# Error processing row 48588: list index out of range
# Error processing row 48646: list index out of range
# Error processing row 49184: list index out of range
# Error processing row 49242: list index out of range
# Error processing row 49300: list index out of range
# Error processing row 50096: list index out of range
# Error processing row 50518: list index out of range
# Error processing row 52250: list index out of range
# Error processing row 52308: list index out of range
# Error processing row 58101: list index out of range
# Error processing row 59545: list index out of range
# Error processing row 59603: list index out of range
# Error processing row 61868: list index out of range
# Error processing row 63144: list index out of range
# Error processing row 67448: list index out of range
# Error processing row 67678: list index out of range
# Error processing row 67709: list index out of range
# Error processing row 67960: list index out of range
# Error processing row 69410: list index out of range
# Error processing row 69526: list index out of range
# Error processing row 69584: list index out of range
# Error processing row 69758: list index out of range
# Error processing row 69816: list index out of range
# Error processing row 69874: list index out of range
# Error processing row 69932: list index out of range
# Error processing row 71231: list index out of range
# Error processing row 71289: list index out of range
# Error processing row 71347: list index out of range
# Error processing row 71405: list index out of range
# Error processing row 71931: list index out of range
# Error processing row 72252: list index out of range
# Error processing row 73059: list index out of range
# Error processing row 73117: list index out of range
# Error processing row 73233: list index out of range
# Error processing row 73291: list index out of range
# Error processing row 73349: list index out of range
# Error processing row 76605: list index out of range
# Error processing row 80497: list index out of range
# Error processing row 80555: list index out of range
# Error processing row 81614: list index out of range
# Error processing row 83124: list index out of range
# Error processing row 88666: list index out of range
# Error processing row 88724: list index out of range
# Error processing row 88782: list index out of range
# Error processing row 89130: list index out of range
# Error processing row 89256: list index out of range
# Error processing row 91108: list index out of range
# Error processing row 92050: list index out of range
# Error processing row 92222: list index out of range
# Error processing row 92338: list index out of range
# Error processing row 92396: list index out of range
# Error processing row 93810: list index out of range
# Error processing row 100065: list index out of range
# Error processing row 104982: list index out of range
# Error processing row 105098: list index out of range
# Error processing row 105504: list index out of range
# Error processing row 105910: list index out of range

# %%
print(len(exception_df_re))
print(exception_df_re.isnull().sum())
# Out:
# 104
# name            15
# sum_pop          0
# geometry_x       0
# cen              0
# Popid            0
# longitude_x      0
# latitude_x       0
# area             0
# Natureparkid     0
# count            0
# avg_area         0
# longitude_y      0
# latitude_y       0
# polygonStr       0
# geometry_y       0
# length           0
# lng_x_gcj02      0
# lat_x_gcj02      0
# lng_y_gcj02      0
# lat_y_gcj02      0
# distance        99
# cost            99
# dtype: int64

# %%
nan_distance_df = exception_df_re[exception_df_re['distance'].isna()]

# %%
# 调用高德路径规划api-步行，计算路径距离distance（米），耗时cost（秒）
# 路径规划1.0
import json
from urllib import request

def fetch_GaodeMap_walking(df):
    urlbase = 'https://restapi.amap.com/v3/direction/walking?&key=225cfe7d506a6037debd6a9f4d5aa583&origin={0},{1}&destination={2},{3}'
    distances = []
    costs = []
    exceptions = []  # 用来收集引发异常的行索引

    for i, row in df.iterrows():
        x1 = row['lng_x_gcj02']
        y1 = row['lat_x_gcj02']
        x2 = row['lng_y_gcj02']
        y2 = row['lat_y_gcj02']
        url = urlbase.format(x1, y1, x2, y2)

        try:
            html = request.urlopen(url, timeout=15).read()
            js = json.loads(html)
            distance = js['route']['paths'][0]['distance']
            cost = js['route']['paths'][0]['duration']
        except Exception as e:
            print(f"Error processing row {i}: {e}")
            distance = None
            cost = None
            exceptions.append(i)  # 将引发异常的行索引添加到列表中

        distances.append(distance)
        costs.append(cost)

    df['distance'] = distances
    df['cost'] = costs

    return df, exceptions

# %%
# 距离过近的OD，使用步行替代公交计算交通耗时
exception_nan_distance_df,exception = fetch_GaodeMap_walking(nan_distance_df)

# %%
exception
# Out:
# []

# %%
nan_distance_df['distance'] = nan_distance_df['distance'].combine_first(exception_nan_distance_df['distance'])
nan_distance_df['cost'] = nan_distance_df['cost'].combine_first(exception_nan_distance_df['cost'])

# %%
exception_df_re['distance'] = exception_df_re['distance'].combine_first(nan_distance_df['distance'])
exception_df_re['cost'] = exception_df_re['cost'].combine_first(nan_distance_df['cost'])

# %%
ODe_Gaode['distance'] = ODe_Gaode['distance'].combine_first(exception_df_re['distance'])
ODe_Gaode['cost'] = ODe_Gaode['cost'].combine_first(exception_df_re['cost'])

# %%
print(ODe_Gaode.isnull().sum())
# Out:
# name            2238
# sum_pop            0
# geometry_x         0
# cen                0
# Popid              0
# longitude_x        0
# latitude_x         0
# area               0
# Natureparkid       0
# count              0
# avg_area           0
# longitude_y        0
# latitude_y         0
# polygonStr         0
# geometry_y         0
# length             0
# lng_x_gcj02        0
# lat_x_gcj02        0
# lng_y_gcj02        0
# lat_y_gcj02        0
# distance           0
# cost               0
# dtype: int64

# %%
print(ODe_Gaode['Popid'].nunique())
# Out:
# 1828

# %%
# 7 转换为数
ODe_Gaode['cost'] = ODe_Gaode['cost'].astype(float)
ODe_Gaode['distance'] = ODe_Gaode['distance'].astype(float)

# %%
ODe_Gaode.describe()
# Out:
#             sum_pop        Popid  longitude_x   latitude_x          area  \
# count   7749.000000  7749.000000  7749.000000  7749.000000  7.749000e+03
# mean    1094.797044  1105.459414   114.035080    22.594870  1.594633e+07
# std     1729.088717   575.467112     0.132602     0.069812  1.632977e+07
# min        3.078762     1.000000   113.773104    22.474726  3.116790e+05
# 25%      280.235872   696.000000   113.929621    22.542556  4.675047e+05
# 50%      583.720867  1142.000000   114.028315    22.573057  5.026383e+06
# 75%     1186.549446  1596.000000   114.084853    22.637903  2.759344e+07
# max    26058.146784  2081.000000   114.585661    22.808439  5.492925e+07
#
#        Natureparkid        count      avg_area  longitude_y   latitude_y  \
# count   7749.000000  7749.000000  7.749000e+03  7749.000000  7749.000000
# mean       4.618015    10.842302  1.016590e+06   114.017385    22.599318
# std        2.541583     9.013880  6.856190e+05     0.135146     0.058752
# min        1.000000     1.000000  3.116790e+05   113.823613    22.503005
# 25%        2.000000     1.000000  4.675047e+05   113.932237    22.539463
# 50%        5.000000     6.000000  8.377306e+05   113.984552    22.606356
# 75%        6.000000    20.000000  1.623143e+06   114.049479    22.632964
# max        9.000000    22.000000  3.661950e+06   114.569193    22.727077
#
#              length  lng_x_gcj02  lat_x_gcj02  lng_y_gcj02  lat_y_gcj02  \
# count   7749.000000  7749.000000  7749.000000  7749.000000  7749.000000
# mean   10324.411441   114.040068    22.592023   114.022349    22.596436
# std     5119.689296     0.132613     0.069850     0.135143     0.058789
# min       76.327740   113.778255    22.471811   113.828646    22.499974
# 25%     6345.055311   113.934483    22.539505   113.937110    22.536549
# 50%    10013.537858   114.033377    22.570284   113.989508    22.603488
# 75%    14510.270454   114.089982    22.635208   114.054584    22.630292
# max    19992.857824   114.590156    22.805480   114.573699    22.724254
#
#            distance          cost
# count   7749.000000   7749.000000
# mean   16241.344044   4137.833656
# std     8017.484053   1624.038813
# min       80.000000     64.000000
# 25%    10188.000000   3029.000000
# 50%    16130.000000   3990.000000
# 75%    21474.000000   4880.000000
# max    70134.000000  32942.000000

# %%
# 存储
ODe_Gaode.to_csv('tmp/ODe_Gaode.csv',index=False,encoding='utf-8')

# %%
# 8 以60min，即3600s为阈值，计算Ga2SFCA,得到每个popcell的可达性
f_ODe_Gaode = ODe_Gaode[ODe_Gaode['cost'] <= 3600]

f_ODe_Gaode.reset_index(drop = True, inplace = True)

print(len(f_ODe_Gaode))
print(len(f_ODe_Gaode['Popid'].unique()))
# Out:
# 2971
# 1415

# %%
# 9 定义函数
def Ga_3600s(dij):
    e=math.exp(1)
    g=(e**(-0.5*(dij/3600)**2)-e**(-0.5))/(1-e**(-0.5)) # dij是供给和需求之间的长度（时间cost or 距离distance），3600s是阈值（时长or距离）
    return g

def Get_Rj(x):
    x=x.reset_index()
    Sj=x['area'][0]
    
    dt=0
    for i in range(len(x)):
        vl=x['sum_pop'][i]*Ga_3600s(x['cost'][i])
        dt=dt+vl
    return Sj/dt

def Get_Ai(x):
    x=x.reset_index()
    
    dt=0
    for i in range(len(x)):
        vl=x['Rj'][i]*Ga_3600s(x['cost'][i])
        dt=dt+vl
    return dt

# %%
# 10 step1 计算每个公园的Rj
# 公园面积 ➗ 该公园搜索阈以内的人口数

park_s5 = f_ODe_Gaode.groupby(by='Natureparkid').apply(Get_Rj).reset_index()
park_s5 = park_s5.rename(columns={0: 'Rj'})

f_ODe_Gaode = pd.merge(f_ODe_Gaode,park_s5[['Natureparkid', 'Rj']], on='Natureparkid', how='left')

# %%
park_s5
# Out:
#    Natureparkid            Rj
# 0             1      2.781400
# 1             2    367.531753
# 2             3    302.161815
# 3             4  49457.721801
# 4             5      0.923271
# 5             6     60.137390
# 6             7    632.599610
# 7             8     21.087174
# 8             9     35.463360

# %%
f_ODe_Gaode.columns
# Out:
# Index(['name', 'sum_pop', 'geometry_x', 'cen', 'Popid', 'longitude_x',
#        'latitude_x', 'area', 'Natureparkid', 'count', 'avg_area',
#        'longitude_y', 'latitude_y', 'polygonStr', 'geometry_y', 'length',
#        'lng_x_gcj02', 'lat_x_gcj02', 'lng_y_gcj02', 'lat_y_gcj02', 'distance',
#        'cost', 'Rj'],
#       dtype='object')

# %%
# 11 step2 计算每个pop cell的Ai
# 每个供给点popcell,搜索阈以内的Rj,即park_v1
pop_s5 = f_ODe_Gaode.groupby(by='Popid').apply(Get_Ai).reset_index()
pop_s5 = pop_s5.rename(columns={0: 'Ai'})

f_ODe_Gaode = pd.merge(f_ODe_Gaode,pop_s5[['Popid', 'Ai']], on='Popid', how='left')

# %%
pop_s5
# Out:
#       Popid            Ai
# 0         1    555.716015
# 1         2  27598.516217
# 2         4      0.956835
# 3         5     23.576301
# 4         8      5.102206
# ...     ...           ...
# 1410   2076     97.332734
# 1411   2077    172.896879
# 1412   2078     79.143581
# 1413   2079    304.562810
# 1414   2080    357.689075
#
# [1415 rows x 2 columns]

# %%
print(len(f_ODe_Gaode))
print(len(f_ODe_Gaode['Popid'].unique()))
# Out:
# 2971
# 1415

# %%
# 12 简化
access_socre_e = f_ODe_Gaode[['Popid', 'sum_pop', 'geometry_x', 'Ai']]
access_socre_e = access_socre_e.rename(columns={'geometry_x':'geometry'})
access_socre_e.drop_duplicates(inplace=True)
len(access_socre_e)
# Out:
# 1415

# %%
print(len(access_socre_e['Popid'].unique()))
# Out:
# 1415

# %%
print(len(access_socre_e))
# Out:
# 1415

# %%
#13 存储
result_e = pop_resid.merge(access_socre_e[['Popid', 'Ai']], on='Popid', how='left')
result_e = result_e[['sum_pop', 'geometry', 'Popid', 'Ai']]

# %%
result_e.fillna(0, inplace=True)

# %%
result_e.to_file('tmp/result_e.geojson')
